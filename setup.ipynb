# %% [markdown]
# # Setup

# %% [markdown]
# ### Setup Anaconda Environment

# %%
# EDA
# %pip install ipykernel
# %pip install ipywidgets
# %pip install --upgrade nbformat
# %pip install pandas
# %pip install sqlalchemy
# %pip install psycopg2
# %pip install matplotlib
# %pip install seaborn
# %pip install plotly
# Out:
# Requirement already satisfied: ipykernel in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (6.25.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipykernel) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipykernel) (8.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipykernel) (8.3.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipykernel) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipykernel) (1.5.6)
# Requirement already satisfied: packaging in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipykernel) (23.1)
# Requirement already satisfied: psutil in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipykernel) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipykernel) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: backcall in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.0)
# Requirement already satisfied: pickleshare in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.2)
# Requirement already satisfied: colorama in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (305.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.6)
# Requirement already satisfied: six>=1.5 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting nbformat
#   Obtaining dependency information for nbformat from https://files.pythonhosted.org/packages/f4/e7/ef30a90b70eba39e675689b9eaaa92530a71d7435ab8f9cae520814e0caf/nbformat-5.9.2-py3-none-any.whl.metadata
#   Using cached nbformat-5.9.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting fastjsonschema (from nbformat)
#   Obtaining dependency information for fastjsonschema from https://files.pythonhosted.org/packages/9d/93/a3ca3cdeb84065d7d8f8df4cb09ab44405f109183c1d2b915ec17574e6b1/fastjsonschema-2.18.0-py3-none-any.whl.metadata
#   Using cached fastjsonschema-2.18.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting jsonschema>=2.6 (from nbformat)
#   Obtaining dependency information for jsonschema>=2.6 from https://files.pythonhosted.org/packages/2b/ff/af59fd34bc4d7ac3e6e0cd1f3c10317d329b6c1aee179e8b24ad9a79fbac/jsonschema-4.19.0-py3-none-any.whl.metadata
#   Downloading jsonschema-4.19.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: jupyter-core in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from nbformat) (5.3.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from nbformat) (5.9.0)
# Collecting attrs>=22.2.0 (from jsonschema>=2.6->nbformat)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat)
#   Obtaining dependency information for jsonschema-specifications>=2023.03.6 from https://files.pythonhosted.org/packages/1c/24/83349ac2189cc2435e84da3f69ba3c97314d3c0622628e55171c6798ed80/jsonschema_specifications-2023.7.1-py3-none-any.whl.metadata
#   Using cached jsonschema_specifications-2023.7.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat)
#   Obtaining dependency information for referencing>=0.28.4 from https://files.pythonhosted.org/packages/be/8e/56d6f1e2d591f4d6cbcba446cac4a1b0dc4f584537e2071d9bcee8eeab6b/referencing-0.30.2-py3-none-any.whl.metadata
#   Using cached referencing-0.30.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat)
#   Obtaining dependency information for rpds-py>=0.7.1 from https://files.pythonhosted.org/packages/f2/3d/8975137ec6106fa4a08f8e6cbc883eb544801c9f01bf67ca7f02abbf0c1f/rpds_py-0.10.0-cp311-none-win_amd64.whl.metadata
#   Downloading rpds_py-0.10.0-cp311-none-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from jupyter-core->nbformat) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from jupyter-core->nbformat) (305.1)
# Using cached nbformat-5.9.2-py3-none-any.whl (77 kB)
# Downloading jsonschema-4.19.0-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.4 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#    ----------------------------- ---------- 61.4/83.4 kB 825.8 kB/s eta 0:00:01
#    ---------------------------------------- 83.4/83.4 kB 937.7 kB/s eta 0:00:00
# Using cached fastjsonschema-2.18.0-py3-none-any.whl (23 kB)
# Using cached jsonschema_specifications-2023.7.1-py3-none-any.whl (17 kB)
# Using cached referencing-0.30.2-py3-none-any.whl (25 kB)
# Downloading rpds_py-0.10.0-cp311-none-win_amd64.whl (184 kB)
#    ---------------------------------------- 0.0/184.5 kB ? eta -:--:--
#    --------------------------------------- 184.5/184.5 kB 11.6 MB/s eta 0:00:00
# Installing collected packages: fastjsonschema, rpds-py, attrs, referencing, jsonschema-specifications, jsonschema, nbformat
# Successfully installed attrs-23.1.0 fastjsonschema-2.18.0 jsonschema-4.19.0 jsonschema-specifications-2023.7.1 nbformat-5.9.2 referencing-0.30.2 rpds-py-0.10.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/b7/f8/32d6b5aa4c4bc045fa2c4c58f88c325facc54721956c6313f0afea8ea853/pandas-2.1.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading pandas-2.1.0-cp311-cp311-win_amd64.whl.metadata (18 kB)
# Collecting numpy>=1.23.2 (from pandas)
#   Obtaining dependency information for numpy>=1.23.2 from https://files.pythonhosted.org/packages/72/b2/02770e60c4e2f7e158d923ab0dea4e9f146a2dbf267fec6d8dc61d475689/numpy-1.25.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached numpy-1.25.2-cp311-cp311-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1 (from pandas)
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: six>=1.5 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.1.0-cp311-cp311-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.0 MB 1.8 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/11.0 MB 4.7 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/11.0 MB 5.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.1/11.0 MB 5.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/11.0 MB 6.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/11.0 MB 6.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.2/11.0 MB 6.9 MB/s eta 0:00:02
#    --------- ------------------------------ 2.7/11.0 MB 7.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.2/11.0 MB 8.2 MB/s eta 0:00:01
#    ------------ --------------------------- 3.4/11.0 MB 8.3 MB/s eta 0:00:01
#    ------------- -------------------------- 3.7/11.0 MB 7.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.7/11.0 MB 9.1 MB/s eta 0:00:01
#    ------------------- -------------------- 5.4/11.0 MB 9.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.4/11.0 MB 10.4 MB/s eta 0:00:01
#    -------------------------- ------------- 7.4/11.0 MB 11.5 MB/s eta 0:00:01
#    ------------------------------ --------- 8.5/11.0 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.5/11.0 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------  10.9/11.0 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 14.2 MB/s eta 0:00:00
# Using cached numpy-1.25.2-cp311-cp311-win_amd64.whl (15.5 MB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.25.2 pandas-2.1.0 pytz-2023.3 tzdata-2023.3
# Note: you may need to restart the kernel to use updated packages.
# Collecting sqlalchemy
#   Obtaining dependency information for sqlalchemy from https://files.pythonhosted.org/packages/10/81/230bec5713913a472003b71c8dd7e3572de44499e741df576fd6b39d82c8/SQLAlchemy-2.0.20-cp311-cp311-win_amd64.whl.metadata
#   Downloading SQLAlchemy-2.0.20-cp311-cp311-win_amd64.whl.metadata (9.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from sqlalchemy) (4.7.1)
# Collecting greenlet!=0.4.17 (from sqlalchemy)
#   Using cached greenlet-2.0.2-cp311-cp311-win_amd64.whl (192 kB)
# Downloading SQLAlchemy-2.0.20-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.0 MB 667.8 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.2/2.0 MB 2.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.2/2.0 MB 2.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.2/2.0 MB 2.5 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.0 MB 2.8 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.0 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 6.5 MB/s eta 0:00:00
# Installing collected packages: greenlet, sqlalchemy
# Successfully installed greenlet-2.0.2 sqlalchemy-2.0.20
# Note: you may need to restart the kernel to use updated packages.
# Collecting psycopg2
#   Obtaining dependency information for psycopg2 from https://files.pythonhosted.org/packages/7b/69/3afcafc622a52bbe90da947411a063a6f33ecc7243bad7b31fe358db92ff/psycopg2-2.9.7-cp311-cp311-win_amd64.whl.metadata
#   Using cached psycopg2-2.9.7-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# Using cached psycopg2-2.9.7-cp311-cp311-win_amd64.whl (1.2 MB)
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.7
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/4d/9c/65830d4a56c47f5283eaa244dc1228c5da9c844a9f999ebcc2e69bf6cc65/matplotlib-3.7.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached matplotlib-3.7.2-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/16/09/989b982322439faa4bafffcd669e6f942b38fee897c2664c987bcd091dec/contourpy-1.1.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached contourpy-1.1.0-cp311-cp311-win_amd64.whl.metadata (5.7 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/95/b6/9a5133deb5838c4dbe3ea27e8dba123622aa5112d43a079e9587636b4faf/fonttools-4.42.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading fonttools-4.42.1-cp311-cp311-win_amd64.whl.metadata (154 kB)
#      ---------------------------------------- 0.0/154.1 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/154.1 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/154.1 kB 435.7 kB/s eta 0:00:01
#      -------------- ---------------------- 61.4/154.1 kB 544.7 kB/s eta 0:00:01
#      -------------- ---------------------- 61.4/154.1 kB 544.7 kB/s eta 0:00:01
#      -----------------------------------  153.6/154.1 kB 833.5 kB/s eta 0:00:01
#      ------------------------------------ 154.1/154.1 kB 765.1 kB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.0.1 from https://files.pythonhosted.org/packages/1e/37/d3c2d4ba2719059a0f12730947bbe1ad5ee8bff89e8c35319dcb2c9ddb4c/kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from matplotlib) (23.1)
# Collecting pillow>=6.2.0 (from matplotlib)
#   Obtaining dependency information for pillow>=6.2.0 from https://files.pythonhosted.org/packages/66/d4/054e491f0880bf0119ee79cdc03264e01d5732e06c454da8c69b83a7c8f2/Pillow-10.0.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached Pillow-10.0.0-cp311-cp311-win_amd64.whl.metadata (9.6 kB)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.7.2-cp311-cp311-win_amd64.whl (7.5 MB)
# Using cached contourpy-1.1.0-cp311-cp311-win_amd64.whl (470 kB)
# Downloading fonttools-4.42.1-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/2.1 MB 4.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/2.1 MB 7.8 MB/s eta 0:00:01
#    -------------------------- ------------- 1.4/2.1 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 13.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Using cached Pillow-10.0.0-cp311-cp311-win_amd64.whl (2.5 MB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.0 cycler-0.11.0 fonttools-4.42.1 kiwisolver-1.4.5 matplotlib-3.7.2 pillow-10.0.0 pyparsing-3.0.9
# Note: you may need to restart the kernel to use updated packages.
# Collecting seaborn
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting plotly
#   Obtaining dependency information for plotly from https://files.pythonhosted.org/packages/26/5d/1e13b597ed8e54803e9ac6ded18c04cd35d8cbc49016778ec50c4ca9e9d5/plotly-5.16.1-py2.py3-none-any.whl.metadata
#   Downloading plotly-5.16.1-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Obtaining dependency information for tenacity>=6.2.0 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: packaging in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from plotly) (23.1)
# Downloading plotly-5.16.1-py2.py3-none-any.whl (15.6 MB)
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB 660.6 kB/s eta 0:00:24
#    ---------------------------------------- 0.1/15.6 MB 1.1 MB/s eta 0:00:15
#    - -------------------------------------- 0.6/15.6 MB 4.3 MB/s eta 0:00:04
#    --- ------------------------------------ 1.2/15.6 MB 7.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.0/15.6 MB 10.0 MB/s eta 0:00:02
#    ------- -------------------------------- 3.0/15.6 MB 11.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.9/15.6 MB 13.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 4.7/15.6 MB 14.2 MB/s eta 0:00:01
#    -------------- ------------------------- 5.5/15.6 MB 14.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.5/15.6 MB 15.3 MB/s eta 0:00:01
#    ------------------ --------------------- 7.3/15.6 MB 16.1 MB/s eta 0:00:01
#    -------------------- ------------------- 8.2/15.6 MB 16.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.8/15.6 MB 16.0 MB/s eta 0:00:01
#    ------------------------ --------------- 9.7/15.6 MB 16.3 MB/s eta 0:00:01
#    --------------------------- ------------ 10.9/15.6 MB 21.8 MB/s eta 0:00:01
#    ------------------------------ --------- 12.0/15.6 MB 21.8 MB/s eta 0:00:01
#    --------------------------------- ------ 12.9/15.6 MB 21.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.0/15.6 MB 21.8 MB/s eta 0:00:01
#    -------------------------------------- - 15.1/15.6 MB 22.5 MB/s eta 0:00:01
#    ---------------------------------------  15.6/15.6 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.6/15.6 MB 20.5 MB/s eta 0:00:00
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.16.1 tenacity-8.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# Model Training
# %pip install transformers
# %pip install scikit-learn
# %pip install chardet
# Out:
# Requirement already satisfied: transformers in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (4.32.1)
# Requirement already satisfied: filelock in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from transformers) (3.12.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: requests in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: colorama in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from requests->transformers) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from scikit-learn) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dillo\anaconda3\envs\watson\lib\site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting chardet
#   Obtaining dependency information for chardet from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ---------------------------------------- 0.0/199.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/199.4 kB ? eta -:--:--
#    ------ -------------------------------- 30.7/199.4 kB 435.7 kB/s eta 0:00:01
#    ------------------ -------------------- 92.2/199.4 kB 871.5 kB/s eta 0:00:01
#    ---------------------------------------- 199.4/199.4 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: chardet
# Successfully installed chardet-5.2.0
# Note: you may need to restart the kernel to use updated packages.
